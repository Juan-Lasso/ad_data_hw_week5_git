# %%
## import pandas library 
import pandas as pd

# %%
#import data and store as data frame
ms2020_excerpt_df = pd.read_csv("data-raw/ems20_1st_6months_excerpt.csv")

# %%
#call the first 10 rows 
ms2020_excerpt_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
# 7        201471743  2020-05-26 12:45:46            INJURY
# 8        201180116  2020-04-27 00:57:48               EDP
# 9        200572739  2020-02-26 15:15:25            CARDBR
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# ...

# %%
#call the last five rows
ms2020_excerpt_df.tail(5)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# ...

# %%
## call a 20 random rows
ms2020_excerpt_df.sample(20)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 2193         201692153  2020-06-17 15:02:23            MEDRXN
# 9145         201362959  2020-05-15 18:24:58              CVAC
# 12367        200370478  2020-02-06 03:48:34              SICK
# 10278        201413757  2020-05-20 23:31:47              CARD
# 8147         200935825  2020-04-02 21:17:39            DIFFBR
# 936          201373907  2020-05-16 23:09:37            INJURY
# 9185         200344609  2020-02-03 20:57:53            UNKNOW
# 11251        200571889  2020-02-26 12:04:57              SICK
# 995          201322074  2020-05-11 14:43:39            SICMIN
# 6693         201772451  2020-06-25 15:54:21            CARDBR
# 9235         201182907  2020-04-27 18:40:45              CVAC
# 9664         201823749  2020-06-30 21:53:48              SHOT
# 170          200323090  2020-02-01 16:57:55            INJURY
# 6614         201541523  2020-06-02 11:34:56            INJURY
# ...

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there
ms2020_excerpt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13117 entries, 0 to 13116
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CAD_INCIDENT_ID                 13117 non-null  int64
#  1   INCIDENT_DATETIME               13117 non-null  object
#  2   INITIAL_CALL_TYPE               13117 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     13117 non-null  int64
#  4   FINAL_CALL_TYPE                 13117 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       13117 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       13010 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  13117 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    13117 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       12988 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         12533 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  13117 non-null  object
# ...

# %%
#There are integers, objects, and floats
#There are 32 columns

# %%
## call the top 7 rows
ms2020_excerpt_df.head(7)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# ...

# %%
## call a sample of 10
ms2020_excerpt_df.sample(10)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 4403         201163702  2020-04-25 22:24:44             OTHER
# 138          201004005  2020-04-09 17:31:24            CDBRFC
# 1528         200143685  2020-01-14 18:45:20            RESPIR
# 11272        200340026  2020-02-03 00:06:53              SICK
# 7132         201730636  2020-06-21 03:48:36             MCI21
# 6637         200260747  2020-01-26 04:41:50            DIFFBR
# 2941         200974796  2020-04-06 17:15:47            SICMIN
# 10996        201383095  2020-05-17 20:41:56              DRUG
# 724          200794578  2020-03-19 21:12:02               EDP
# 12325        201160525  2020-04-25 04:30:20              CARD
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 4403                             6            EDPC                          7
# 138                              2          CDBRFC                          2
# ...

# %%
## call the bottom 6
ms2020_excerpt_df.tail(6)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13111        200870168  2020-03-27 00:42:59            INJURY
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13111                            5          INJURY                          5
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# ...

# %%
## Programmatically capture the 2245th FINAL_CALL_TYPE value and store in a variable.
target_value = ms2020_excerpt_df["FINAL_CALL_TYPE"].iat[2244]

# %%
target_value
# Out:
# 'STAB'

# %%
## import Excel data here
cbp_df = pd.read_excel("data-raw/multi-data.xlsx", sheet_name = 2, skiprows = 6)

# %%
## call the top 15 rows
cbp_df.head(15)
# Out:
#                date_in            date_out  hours_in_custody     age_group  \
# 0  2017-01-20 00:10:00 2017-01-20 10:08:00          9.950000     6-8 years
# 1  2017-01-20 00:15:00 2017-01-24 17:30:00        113.233333     3-5 years
# 2  2017-01-20 00:22:00 2017-01-24 17:47:00        113.416667     3-5 years
# 3  2017-01-20 00:30:00 2017-01-21 06:35:00         30.083333   12-14 years
# 4  2017-01-20 00:30:00 2017-01-21 13:03:00         36.533333     3-5 years
# 5  2017-01-20 00:30:00 2017-01-21 15:30:00         38.983333  Under 1 year
# 6  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     6-8 years
# 7  2017-01-20 00:35:00 2017-01-20 15:14:00         14.633333     6-8 years
# 8  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     3-5 years
# 9  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667    9-11 years
# 10 2017-01-20 00:45:00 2017-01-20 13:15:00         12.500000   15-18 years
# ...

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there
cbp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95721 entries, 0 to 95720
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_in           95721 non-null  datetime64[ns]
#  1   date_out          95223 non-null  datetime64[ns]
#  2   hours_in_custody  95506 non-null  float64
#  3   age_group         95716 non-null  object
#  4   gender            95721 non-null  object
#  5   citizenship       95721 non-null  object
#  6   border            95721 non-null  object
#  7   sector            95721 non-null  object
#  8   field_office      0 non-null      float64
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 6.6+ MB

# %%
# The data types are floats, objects, and datetimes 
#There are 9 columns and 95721 rows

# %%
## call the bottom 3
cbp_df.tail(3)
# Out:
#                   date_in            date_out  hours_in_custody    age_group  \
# 95718 2018-06-02 13:05:00 2018-06-05 23:35:00         82.483333    6-8 years
# 95719 2018-06-02 13:05:00 2018-06-04 00:54:00         35.800000  15-18 years
# 95720 2018-06-02 13:20:00 2018-06-06 07:27:00         90.100000    6-8 years
#
#        gender citizenship border      sector  field_office
# 95718  Female   GUATEMALA    SBO  (b)(7)(E )           NaN
# 95719    Male   GUATEMALA    SBO  (b)(7)(E )           NaN
# 95720    Male   GUATEMALA    SBO  (b)(7)(E )           NaN

# %%
## call a sample of 20
cbp_df.sample(20)
# Out:
#                   date_in            date_out  hours_in_custody    age_group  \
# 76037 2018-04-08 21:30:00 2018-04-10 13:31:00         40.000000  15-18 years
# 74665 2018-04-03 12:00:00 2018-04-03 16:47:00          4.766667  15-18 years
# 39598 2017-11-12 19:22:00 2017-11-14 11:45:00         40.366667    3-5 years
# 26965 2017-09-06 16:00:00 2017-09-08 05:10:00         37.150000   9-11 years
# 41613 2017-11-20 14:29:00 2017-11-22 11:11:00         44.700000  15-18 years
# 74772 2018-04-03 19:35:00 2018-04-05 11:06:00         39.500000  15-18 years
# 23987 2017-08-21 17:50:00 2017-08-23 15:45:00         45.900000    3-5 years
# 73988 2018-03-30 23:35:00 2018-04-03 08:56:00         81.333333    1-2 years
# 58442 2018-01-27 20:00:00 2018-01-28 16:39:00         20.616667  15-18 years
# 39175 2017-11-10 20:55:00 2017-11-13 14:25:00         65.483333    3-5 years
# 67920 2018-03-11 01:15:00 2018-03-14 09:32:00         80.266667    6-8 years
# ...

# %%
## Programmatically capture the 8th hours_in_custody value and store in a variable.
target_value = cbp_df["hours_in_custody"].iat[7]

# %%
target_value
# Out:
# 14.6333333333333
